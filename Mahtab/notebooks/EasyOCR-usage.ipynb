# %%
# !pip install easyocr opencv-python

import sys
sys.path.append('../cores')
from easyocr_core import easyOCR
import json
import re
import cv2
import numpy as np
# Out:
# Requirement already satisfied: easyocr in /home/mohsen/Desktop/homelab/mahta/Mahtab/venv/lib/python3.12/site-packages (1.7.2)
# Requirement already satisfied: opencv-python in /home/mohsen/Desktop/homelab/mahta/Mahtab/venv/lib/python3.12/site-packages (4.12.0.88)
# Requirement already satisfied: torch in /home/mohsen/Desktop/homelab/mahta/Mahtab/venv/lib/python3.12/site-packages (from easyocr) (2.9.1)
# Requirement already satisfied: torchvision>=0.5 in /home/mohsen/Desktop/homelab/mahta/Mahtab/venv/lib/python3.12/site-packages (from easyocr) (0.24.1)
# Requirement already satisfied: opencv-python-headless in /home/mohsen/Desktop/homelab/mahta/Mahtab/venv/lib/python3.12/site-packages (from easyocr) (4.12.0.88)
# Requirement already satisfied: scipy in /home/mohsen/Desktop/homelab/mahta/Mahtab/venv/lib/python3.12/site-packages (from easyocr) (1.16.3)
# Requirement already satisfied: numpy in /home/mohsen/Desktop/homelab/mahta/Mahtab/venv/lib/python3.12/site-packages (from easyocr) (2.2.6)
# Requirement already satisfied: Pillow in /home/mohsen/Desktop/homelab/mahta/Mahtab/venv/lib/python3.12/site-packages (from easyocr) (12.0.0)
# Requirement already satisfied: scikit-image in /home/mohsen/Desktop/homelab/mahta/Mahtab/venv/lib/python3.12/site-packages (from easyocr) (0.25.2)
# Requirement already satisfied: python-bidi in /home/mohsen/Desktop/homelab/mahta/Mahtab/venv/lib/python3.12/site-packages (from easyocr) (0.6.7)
# Requirement already satisfied: PyYAML in /home/mohsen/Desktop/homelab/mahta/Mahtab/venv/lib/python3.12/site-packages (from easyocr) (6.0.3)
# Requirement already satisfied: Shapely in /home/mohsen/Desktop/homelab/mahta/Mahtab/venv/lib/python3.12/site-packages (from easyocr) (2.1.2)
# Requirement already satisfied: pyclipper in /home/mohsen/Desktop/homelab/mahta/Mahtab/venv/lib/python3.12/site-packages (from easyocr) (1.3.0.post6)
# Requirement already satisfied: ninja in /home/mohsen/Desktop/homelab/mahta/Mahtab/venv/lib/python3.12/site-packages (from easyocr) (1.13.0)
# Requirement already satisfied: filelock in /home/mohsen/Desktop/homelab/mahta/Mahtab/venv/lib/python3.12/site-packages (from torch->easyocr) (3.20.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /home/mohsen/Desktop/homelab/mahta/Mahtab/venv/lib/python3.12/site-packages (from torch->easyocr) (4.15.0)
# Requirement already satisfied: setuptools in /home/mohsen/Desktop/homelab/mahta/Mahtab/venv/lib/python3.12/site-packages (from torch->easyocr) (80.9.0)
# Requirement already satisfied: sympy>=1.13.3 in /home/mohsen/Desktop/homelab/mahta/Mahtab/venv/lib/python3.12/site-packages (from torch->easyocr) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /home/mohsen/Desktop/homelab/mahta/Mahtab/venv/lib/python3.12/site-packages (from torch->easyocr) (3.5)
# Requirement already satisfied: jinja2 in /home/mohsen/Desktop/homelab/mahta/Mahtab/venv/lib/python3.12/site-packages (from torch->easyocr) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /home/mohsen/Desktop/homelab/mahta/Mahtab/venv/lib/python3.12/site-packages (from torch->easyocr) (2025.10.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /home/mohsen/Desktop/homelab/mahta/Mahtab/venv/lib/python3.12/site-packages (from torch->easyocr) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /home/mohsen/Desktop/homelab/mahta/Mahtab/venv/lib/python3.12/site-packages (from torch->easyocr) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /home/mohsen/Desktop/homelab/mahta/Mahtab/venv/lib/python3.12/site-packages (from torch->easyocr) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /home/mohsen/Desktop/homelab/mahta/Mahtab/venv/lib/python3.12/site-packages (from torch->easyocr) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /home/mohsen/Desktop/homelab/mahta/Mahtab/venv/lib/python3.12/site-packages (from torch->easyocr) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /home/mohsen/Desktop/homelab/mahta/Mahtab/venv/lib/python3.12/site-packages (from torch->easyocr) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /home/mohsen/Desktop/homelab/mahta/Mahtab/venv/lib/python3.12/site-packages (from torch->easyocr) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /home/mohsen/Desktop/homelab/mahta/Mahtab/venv/lib/python3.12/site-packages (from torch->easyocr) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /home/mohsen/Desktop/homelab/mahta/Mahtab/venv/lib/python3.12/site-packages (from torch->easyocr) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /home/mohsen/Desktop/homelab/mahta/Mahtab/venv/lib/python3.12/site-packages (from torch->easyocr) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /home/mohsen/Desktop/homelab/mahta/Mahtab/venv/lib/python3.12/site-packages (from torch->easyocr) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.3.20 in /home/mohsen/Desktop/homelab/mahta/Mahtab/venv/lib/python3.12/site-packages (from torch->easyocr) (3.3.20)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /home/mohsen/Desktop/homelab/mahta/Mahtab/venv/lib/python3.12/site-packages (from torch->easyocr) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /home/mohsen/Desktop/homelab/mahta/Mahtab/venv/lib/python3.12/site-packages (from torch->easyocr) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /home/mohsen/Desktop/homelab/mahta/Mahtab/venv/lib/python3.12/site-packages (from torch->easyocr) (1.13.1.3)
# Requirement already satisfied: triton==3.5.1 in /home/mohsen/Desktop/homelab/mahta/Mahtab/venv/lib/python3.12/site-packages (from torch->easyocr) (3.5.1)
# Requirement already satisfied: imageio!=2.35.0,>=2.33 in /home/mohsen/Desktop/homelab/mahta/Mahtab/venv/lib/python3.12/site-packages (from scikit-image->easyocr) (2.37.2)
# Requirement already satisfied: tifffile>=2022.8.12 in /home/mohsen/Desktop/homelab/mahta/Mahtab/venv/lib/python3.12/site-packages (from scikit-image->easyocr) (2025.10.16)
# Requirement already satisfied: packaging>=21 in /home/mohsen/Desktop/homelab/mahta/Mahtab/venv/lib/python3.12/site-packages (from scikit-image->easyocr) (25.0)
# Requirement already satisfied: lazy-loader>=0.4 in /home/mohsen/Desktop/homelab/mahta/Mahtab/venv/lib/python3.12/site-packages (from scikit-image->easyocr) (0.4)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/mohsen/Desktop/homelab/mahta/Mahtab/venv/lib/python3.12/site-packages (from sympy>=1.13.3->torch->easyocr) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/mohsen/Desktop/homelab/mahta/Mahtab/venv/lib/python3.12/site-packages (from jinja2->torch->easyocr) (3.0.3)

# %%
# Initialize EasyOCR with CPU only (avoid CUDA issues)
import os
os.environ["CUDA_VISIBLE_DEVICES"] = ""

# Create a modified version that forces CPU
import easyocr

class easyOCR_CPU:
    def __init__(self, visualize=False):
        self.reader = easyocr.Reader(['ar', 'fa'], gpu=False)  # Force CPU
        self.visualize = visualize
        self.confidence_threshold = 0.1

    def detect_text(self, image_path: str):
        results = self.reader.readtext(image_path)
        
        if self.visualize:
            image = cv2.imread(image_path)

        detected_text = []
        for (bbox, text, confidence) in results:
            if confidence > self.confidence_threshold:
                confidence = round(float(confidence), 2)
                detected_text.append({'text': text,'confidence': float(confidence)})
                
                if self.visualize:
                    pts = np.array(bbox, dtype=np.int32)
                    cv2.polylines(image, [pts], True, (0, 255, 0), 2)
                
        if self.visualize:
            cv2.imwrite('easyocr_result.jpg', image)
        
        return detected_text

# Initialize with CPU-only version
ocr = easyOCR_CPU(visualize=True)
image_path = "/home/mohsen/Desktop/homelab/mahta/test-data/test-2.jpg"
# Out:
# Using CPU. Note: This module is much faster with a GPU.

# %%
# Extract text using EasyOCR
detected_texts = ocr.detect_text(image_path)

print(f"Total texts detected: {len(detected_texts)}")
for i, item in enumerate(detected_texts):
    print(f"{i+1}. '{item['text']}' (confidence: {item['confidence']})")
# Out:
# Total texts detected: 5
# 1. 'قررت' (confidence: 0.95)
# 2. 'به خودی خودبی طرف لست' (confidence: 0.55)
# 3. 'مابایرم سثولیت ا قراما تماف را' (confidence: 0.27)
# 4. '-رضا بصیر-' (confidence: 0.29)
# 5. 'بعهره بُثیریم .-' (confidence: 0.29)
