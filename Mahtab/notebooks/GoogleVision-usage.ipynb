# %%
from typing import List, Dict, Any
import json
from google.cloud import vision

# %%
client = vision.ImageAnnotatorClient()

# %%
def read_image(image_path: str):
    with open(image_path, 'rb') as image_file:
        image_binary = image_file.read()
    return image_binary

# %%
def detect(image_path: str):
    image_binary = read_image(image_path=image_path)
    image = vision.Image(content=image_binary)
    response = client.document_text_detection(image=image)
    return response

# %%
image_path = "/home/mohsen/Desktop/homelab/mahta/test-data/exame1.jpeg"
detection = detect(image_path=image_path)

# %%
def print_text_by_paragraph(detection):
    for page in detection.full_text_annotation.pages:
        for block in page.blocks:
            for para_num, paragraph in enumerate(block.paragraphs, 1):
                para_text = ""
                for word in paragraph.words:
                    word_text = "".join([symbol.text for symbol in word.symbols])
                    para_text += word_text + " "
                
                print(f"\n¶ Paragraph {para_num} (Confidence: {paragraph.confidence:.2%})")
                print(f"   {para_text.strip()}")

# %%
def analyze_vision_structure(detection):
    """
    Analyze Google Vision API text detection structure and return as JSON
    """
    result = []
    
    total_paragraphs = 0
    
    for page_num, page in enumerate(detection.full_text_annotation.pages):
        page_data = {
            "page_number": page_num + 1,
            "dimensions": {"width": page.width, "height": page.height},
            "blocks": []
        }
        
        for block_num, block in enumerate(page.blocks):
            vertices = block.bounding_box.vertices
            block_data = {
                "block_number": block_num + 1,
                "type": block.block_type,
                "confidence": block.confidence,
                "bounding_box": {
                    "x1": vertices[0].x, "y1": vertices[0].y,
                    "x2": vertices[2].x, "y2": vertices[2].y
                },
                "paragraphs": []
            }
            
            for para_num, paragraph in enumerate(block.paragraphs):
                total_paragraphs += 1
                para_text = " ".join(
                    "".join([symbol.text for symbol in word.symbols])
                    for word in paragraph.words
                )
                
                para_data = {
                    "paragraph_number": para_num + 1,
                    "text": para_text.strip(),
                    "confidence": paragraph.confidence,
                    "words": []
                }
                
                for word_num, word in enumerate(paragraph.words):
                    word_text = "".join([symbol.text for symbol in word.symbols])
                    word_vertices = word.bounding_box.vertices
                    para_data["words"].append({
                        "word_number": word_num + 1,
                        "text": word_text,
                        "position": {"x": word_vertices[0].x, "y": word_vertices[0].y}
                    })
                
                block_data["paragraphs"].append(para_data)
            
            page_data["blocks"].append(block_data)
        
        result.append(page_data)
    
    return result

# %%
# Usage
result = analyze_vision_structure(detection)
print(json.dumps(result, indent=2, ensure_ascii=False))
# Out:
# [
#   {
#     "page_number": 1,
#     "dimensions": {
#       "width": 960,
#       "height": 1280
#     },
#     "blocks": [
#       {
#         "block_number": 1,
#         "type": 1,
#         "confidence": 0.6635594964027405,
#         "bounding_box": {
#           "x1": 823,
#           "y1": 87,
#           "x2": 925,
#           "y2": 113
#         },
#         "paragraphs": [
#           {
#             "paragraph_number": 1,
#             "text": "لأمان",
#             "confidence": 0.6635594964027405,
#             "words": [
#               {
#                 "word_number": 1,
#                 "text": "لأمان",
#                 "position": {
#                   "x": 823,
#                   "y": 87
#                 }
#               }
#             ]
#           }
#         ]
#       },
#       {
#         "block_number": 2,
#         "type": 1,
#         "confidence": 0.9736185073852539,
#         "bounding_box": {
#           "x1": 594,
#           "y1": 106,
# ...

# %%
def organize_blocks_reading_order(
    pages: List[Dict[str, Any]],
    rtl: bool = True,
    vertical_threshold: int = 20
) -> List[Dict[str, Any]]:
    """
    Organize text blocks into natural reading order.

    Args:
        pages: List of page objects with blocks
        rtl: True for right-to-left languages (Persian, Arabic), False for LTR
        vertical_threshold: Y-coordinate difference to consider blocks on same line

    Returns:
        Reorganized pages with blocks in reading order
    """
    organized_pages = []

    for page in pages:
        blocks = page['blocks']

        # Sort blocks into reading order
        sorted_blocks = sort_blocks_by_position(
            blocks,
            rtl=rtl,
            vertical_threshold=vertical_threshold
        )

        # Reassign block numbers
        for idx, block in enumerate(sorted_blocks, 1):
            block['block_number'] = idx
            # Also reorganize paragraphs within each block if needed
            block['paragraphs'] = organize_paragraphs(
                block['paragraphs'],
                rtl=rtl
            )

        organized_page = page.copy()
        organized_page['blocks'] = sorted_blocks
        organized_pages.append(organized_page)

    return organized_pages


def sort_blocks_by_position(
    blocks: List[Dict[str, Any]],
    rtl: bool = True,
    vertical_threshold: int = 20
) -> List[Dict[str, Any]]:
    """
    Sort blocks by their position (top-to-bottom, then right-to-left or left-to-right).

    Args:
        blocks: List of block objects
        rtl: True for right-to-left, False for left-to-right
        vertical_threshold: Pixels difference to consider blocks on same row

    Returns:
        Sorted list of blocks
    """
    if not blocks:
        return blocks

    # Group blocks into rows based on Y-coordinate
    rows = []
    sorted_by_y = sorted(blocks, key=lambda b: b['bounding_box']['y1'])

    current_row = [sorted_by_y[0]]
    current_y = sorted_by_y[0]['bounding_box']['y1']

    for block in sorted_by_y[1:]:
        block_y = block['bounding_box']['y1']

        # If block is roughly at same Y level, add to current row
        if abs(block_y - current_y) <= vertical_threshold:
            current_row.append(block)
        else:
            # Start new row
            rows.append(current_row)
            current_row = [block]
            current_y = block_y

    # Don't forget the last row
    if current_row:
        rows.append(current_row)

    # Sort each row by X-coordinate (RTL: descending, LTR: ascending)
    sorted_blocks = []
    for row in rows:
        if rtl:
            # Right-to-left: sort by x1 descending (rightmost first)
            row_sorted = sorted(row, key=lambda b: b['bounding_box']['x1'], reverse=True)
        else:
            # Left-to-right: sort by x1 ascending (leftmost first)
            row_sorted = sorted(row, key=lambda b: b['bounding_box']['x1'])
        sorted_blocks.extend(row_sorted)

    return sorted_blocks


def organize_paragraphs(
    paragraphs: List[Dict[str, Any]],
    rtl: bool = True
) -> List[Dict[str, Any]]:
    """
    Organize paragraphs within a block by their word positions.

    Args:
        paragraphs: List of paragraph objects
        rtl: True for right-to-left languages

    Returns:
        Reorganized paragraphs (renumbered)
    """
    # For now, just renumber them sequentially
    # In future, could add more sophisticated sorting if needed
    for idx, para in enumerate(paragraphs, 1):
        para['paragraph_number'] = idx
    return paragraphs


def extract_text_in_order(pages: List[Dict[str, Any]]) -> str:
    """
    Extract full text from organized pages in reading order.

    Args:
        pages: List of organized page objects

    Returns:
        Full text string
    """
    text_parts = []

    for page in pages:
        page_text = []
        for block in page['blocks']:
            for paragraph in block['paragraphs']:
                page_text.append(paragraph['text'])
        text_parts.append('\n'.join(page_text))

    return '\n\n'.join(text_parts)



organized_result = organize_blocks_reading_order(result, rtl=True)
print(organized_result)
# Out:
# [{'page_number': 1, 'dimensions': {'width': 960, 'height': 1280}, 'blocks': [{'block_number': 1, 'type': <BlockType.TEXT: 1>, 'confidence': 0.6635594964027405, 'bounding_box': {'x1': 823, 'y1': 87, 'x2': 925, 'y2': 113}, 'paragraphs': [{'paragraph_number': 1, 'text': 'لأمان', 'confidence': 0.6635594964027405, 'words': [{'word_number': 1, 'text': 'لأمان', 'position': {'x': 823, 'y': 87}}]}]}, {'block_number': 2, 'type': <BlockType.TEXT: 1>, 'confidence': 0.9818234443664551, 'bounding_box': {'x1': 446, 'y1': 83, 'x2': 505, 'y2': 99}, 'paragraphs': [{'paragraph_number': 1, 'text': 'به نام خدا', 'confidence': 0.9818234443664551, 'words': [{'word_number': 1, 'text': 'به', 'position': {'x': 494, 'y': 83}}, {'word_number': 2, 'text': 'نام', 'position': {'x': 473, 'y': 83}}, {'word_number': 3, 'text': 'خدا', 'position': {'x': 446, 'y': 83}}]}]}, {'block_number': 3, 'type': <BlockType.TEXT: 1>, 'confidence': 0.9736185073852539, 'bounding_box': {'x1': 594, 'y1': 106, 'x2': 934, 'y2': 147}, 'pa
# ...
