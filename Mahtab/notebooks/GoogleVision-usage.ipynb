# %%
from google.cloud import vision

# %%
client = vision.ImageAnnotatorClient()

# %%
def read_image(image_path: str):
    with open(image_path, 'rb') as image_file:
        image_binary = image_file.read()
    return image_binary

# %%
def detect(image_path: str):
    image_binary = read_image(image_path=image_path)
    image = vision.Image(content=image_binary)
    response = client.document_text_detection(image=image)
    return response

# %%
image_path = "/home/mohsen/Desktop/homelab/mahta/test-data/exame1.jpeg"
detection = detect(image_path=image_path)

# %%
def print_text_by_paragraph(detection):
    for page in detection.full_text_annotation.pages:
        for block in page.blocks:
            for para_num, paragraph in enumerate(block.paragraphs, 1):
                para_text = ""
                for word in paragraph.words:
                    word_text = "".join([symbol.text for symbol in word.symbols])
                    para_text += word_text + " "
                
                print(f"\n¶ Paragraph {para_num} (Confidence: {paragraph.confidence:.2%})")
                print(f"   {para_text.strip()}")

# %%
print_text_by_paragraph(detection)
# Out:
# ¶ Paragraph 1 (Confidence: 66.36%)
#    لأمان
#
# ¶ Paragraph 1 (Confidence: 97.36%)
#    آزمون شبیه ساز نهایی درس سلامت و بهداشت تعداد : صفحه
#
# ¶ Paragraph 1 (Confidence: 98.73%)
#    نام و نام خانوادگی
#
# ¶ Paragraph 1 (Confidence: 97.41%)
#    ردیف
#
# ¶ Paragraph 1 (Confidence: 84.99%)
#    1 .
#
# ¶ Paragraph 1 (Confidence: 72.25%)
#    ۱۲
#
# ¶ Paragraph 1 (Confidence: 92.69%)
#    الف )
#
# ¶ Paragraph 1 (Confidence: 61.60%)
#    Y
#
# ¶ Paragraph 1 (Confidence: 98.18%)
#    به نام خدا
#
# ¶ Paragraph 1 (Confidence: 97.86%)
#    رشته
#
# ¶ Paragraph 1 (Confidence: 96.45%)
#    کلیه رشته ها
#
# ¶ Paragraph 1 (Confidence: 97.03%)
#    ساعت شروع
#
# ¶ Paragraph 1 (Confidence: 97.07%)
#    دوره دوم متوسطه - دوازدهم تاریخ آزمون
#
# ¶ Paragraph 1 (Confidence: 94.60%)
#    پاسخبرگ
#
# ¶ Paragraph 1 (Confidence: 68.31%)
#    ۱۴۰۴/۰۲/۲۵
#
# ¶ Paragraph 1 (Confidence: 98.84%)
#    پاسخهای خود را در محلهای تعیین شده به صورت دقیق خوش خط و مرتب وارد کنید
#
# ¶ Paragraph 1 (Confidence: 87.49%)
#    مدت زمان ۳۰ دقیقه
#
# ¶ Paragraph 1 (Confidence: 92.15%)
#    نمره
#
# ¶ Paragraph 1 (Confidence: 89.77%)
#    قطرات
#
# ¶ Paragraph 1 (Confidence: 82.05%)
#    ب )
#
# ¶ Paragraph 1 (Confidence: 88.80%)
#    نیکوتین
#
# ¶ Paragraph 1 (Confidence: 63.00%)
#    c )
#
# ¶ Paragraph 1 (Confidence: 89.16%)
#    آمونیاک
#
# ¶ Paragraph 1 (Confidence: 94.86%)
#    کشیدن ضامن تمرکز بر روی آتش
#
# ¶ Paragraph 2 (Confidence: 85.27%)
#    اسپری کردن کے فشار آورد
#
# ¶ Paragraph 1 (Confidence: 88.65%)
#    ( الف ) گاز
#
# ¶ Paragraph 1 (Confidence: 79.14%)
#    ب )
#
# ¶ Paragraph 1 (Confidence: 97.52%)
#    برق
#
# ¶ Paragraph 1 (Confidence: 59.90%)
#    ۱۳
#
# ¶ Paragraph 1 (Confidence: 97.60%)
#    بنزین
#
# ¶ Paragraph 1 (Confidence: 92.76%)
#    ج )
#
# ¶ Paragraph 1 (Confidence: 88.44%)
#    ( الف ) دوچر
#
# ¶ Paragraph 1 (Confidence: 79.54%)
#    ب )
#
# ¶ Paragraph 1 (Confidence: 90.94%)
#    موفق باشید .
#
# ¶ Paragraph 1 (Confidence: 55.10%)
#    i >
#
# ¶ Paragraph 1 (Confidence: 85.44%)
#    A
#
# ¶ Paragraph 1 (Confidence: 73.37%)
#    1
#
# ¶ Paragraph 1 (Confidence: 80.61%)
#    ۱.۵
#
# ¶ Paragraph 1 (Confidence: 70.17%)
#    ۲۰

# %%
def analyze_vision_structure(detection):
    """
    Analyze Google Vision API text detection structure
    """
    print("=== Google Vision API Structure Analysis ===\n")
    
    # Overall structure
    print(f"Full text: {detection.full_text_annotation.text[:200]}...")
    print(f"Total pages: {len(detection.full_text_annotation.pages)}\n")
    
    total_paragraphs = 0
    
    # Analyze each page
    for page_num, page in enumerate(detection.full_text_annotation.pages):
        print(f"--- PAGE {page_num + 1} ---")
        print(f"Page dimensions: {page.width} x {page.height}")
        print(f"Total blocks: {len(page.blocks)}\n")
        
        # Analyze each block
        for block_num, block in enumerate(page.blocks):
            print(f"  Block {block_num + 1}:")
            print(f"    Type: {block.block_type}")
            print(f"    Confidence: {block.confidence:.2%}")
            print(f"    Paragraphs: {len(block.paragraphs)}")
            
            # Show bounding box
            vertices = block.bounding_box.vertices
            print(f"    Bounding box: ({vertices[0].x}, {vertices[0].y}) to ({vertices[2].x}, {vertices[2].y})")
            
            # Analyze ALL paragraphs in this block (not just first few)
            for para_num, paragraph in enumerate(block.paragraphs):
                total_paragraphs += 1
                para_text = ""
                for word in paragraph.words:
                    word_text = "".join([symbol.text for symbol in word.symbols])
                    para_text += word_text + " "
                
                print(f"      Para {para_num + 1}: '{para_text.strip()}' (conf: {paragraph.confidence:.2%})")
                
                # Show word details and coordinates for ALL words
                for word_num, word in enumerate(paragraph.words):
                    word_text = "".join([symbol.text for symbol in word.symbols])
                    word_vertices = word.bounding_box.vertices
                    print(f"        Word {word_num + 1}: '{word_text}' at ({word_vertices[0].x}, {word_vertices[0].y})")
            
            print()
    
    print(f"Total paragraphs found: {total_paragraphs}")

analyze_vision_structure(detection)
# Out:
# === Google Vision API Structure Analysis ===
#
# Full text: لأمان
# آزمون شبیه ساز نهایی درس سلامت و بهداشت تعداد :صفحه
# نام و نام خانوادگی
# ردیف
# 1.
# ۱۲
# الف)
# Y
# به نام خدا
# رشته
# کلیه رشته ها
# ساعت شروع
# دوره دوم متوسطه - دوازدهم تاریخ آزمون
# پاسخبرگ
# ۱۴۰۴/۰۲/۲۵
# پاسخهای خ...
# Total pages: 1
#
# --- PAGE 1 ---
# Page dimensions: 960 x 1280
# Total blocks: 38
#
#   Block 1:
#     Type: 1
#     Confidence: 66.36%
#     Paragraphs: 1
#     Bounding box: (823, 87) to (925, 113)
#       Para 1: 'لأمان' (conf: 66.36%)
#         Word 1: 'لأمان' at (823, 87)
#
#   Block 2:
#     Type: 1
#     Confidence: 97.36%
#     Paragraphs: 1
#     Bounding box: (594, 106) to (934, 147)
#       Para 1: 'آزمون شبیه ساز نهایی درس سلامت و بهداشت تعداد : صفحه' (conf: 97.36%)
#         Word 1: 'آزمون' at (905, 126)
#         Word 2: 'شبیه' at (874, 124)
#         Word 3: 'ساز' at (855, 123)
#         Word 4: 'نهایی' at (824, 120)
#         Word 5: 'درس' at (794, 118)
#         Word 6: 'سلامت' at (749, 115)
#         Word 7: 'و' at (738, 115)
#         Word 8: 'بهداشت' at (693, 111)
#         Word 9: 'تعداد' at (633, 113)
#         Word 10: ':' at (618, 113)
#         Word 11: 'صفحه' at (594, 113)
#
#   Block 3:
#     Type: 1
#     Confidence: 98.73%
#     Paragraphs: 1
#     Bounding box: (843, 151) to (935, 172)
#       Para 1: 'نام و نام خانوادگی' (conf: 98.73%)
#         Word 1: 'نام' at (922, 154)
#         Word 2: 'و' at (912, 154)
#         Word 3: 'نام' at (895, 153)
#         Word 4: 'خانوادگی' at (843, 151)
#
#   Block 4:
#     Type: 1
#     Confidence: 97.41%
#     Paragraphs: 1
#     Bounding box: (896, 184) to (929, 200)
#       Para 1: 'ردیف' (conf: 97.41%)
#         Word 1: 'ردیف' at (896, 184)
#
#   Block 5:
#     Type: 1
#     Confidence: 84.99%
#     Paragraphs: 1
#     Bounding box: (922, 571) to (937, 584)
#       Para 1: '1 .' (conf: 84.99%)
#         Word 1: '1' at (922, 572)
#         Word 2: '.' at (927, 571)
#
#   Block 6:
#     Type: 1
#     Confidence: 72.25%
#     Paragraphs: 1
#     Bounding box: (918, 861) to (935, 873)
#       Para 1: '۱۲' (conf: 72.25%)
#         Word 1: '۱۲' at (918, 861)
#
#   Block 7:
#     Type: 1
#     Confidence: 92.69%
#     Paragraphs: 1
#     Bounding box: (861, 414) to (889, 426)
#       Para 1: 'الف )' (conf: 92.69%)
#         Word 1: 'الف' at (865, 414)
#         Word 2: ')' at (861, 414)
#
#   Block 8:
#     Type: 1
#     Confidence: 61.60%
#     Paragraphs: 1
#     Bounding box: (563, 110) to (572, 122)
#       Para 1: 'Y' (conf: 61.60%)
#         Word 1: 'Y' at (563, 110)
#
#   Block 9:
#     Type: 1
#     Confidence: 98.18%
#     Paragraphs: 1
#     Bounding box: (446, 83) to (505, 99)
#       Para 1: 'به نام خدا' (conf: 98.18%)
#         Word 1: 'به' at (494, 83)
#         Word 2: 'نام' at (473, 83)
#         Word 3: 'خدا' at (446, 83)
#
#   Block 10:
#     Type: 1
#     Confidence: 97.86%
#     Paragraphs: 1
#     Bounding box: (435, 112) to (461, 125)
#       Para 1: 'رشته' (conf: 97.86%)
#         Word 1: 'رشته' at (435, 112)
#
#   Block 11:
#     Type: 1
#     Confidence: 96.45%
#     Paragraphs: 1
#     Bounding box: (288, 117) to (362, 126)
#       Para 1: 'کلیه رشته ها' (conf: 96.45%)
#         Word 1: 'کلیه' at (335, 113)
#         Word 2: 'رشته' at (299, 117)
#         Word 3: 'ها' at (288, 118)
#
#   Block 12:
#     Type: 1
#     Confidence: 97.03%
#     Paragraphs: 1
#     Bounding box: (96, 136) to (157, 143)
#       Para 1: 'ساعت شروع' (conf: 97.03%)
#         Word 1: 'ساعت' at (126, 132)
#         Word 2: 'شروع' at (96, 137)
#
#   Block 13:
#     Type: 1
#     Confidence: 97.07%
#     Paragraphs: 1
#     Bounding box: (397, 137) to (650, 158)
#       Para 1: 'دوره دوم متوسطه - دوازدهم تاریخ آزمون' (conf: 97.07%)
#         Word 1: 'دوره' at (621, 137)
#         Word 2: 'دوم' at (595, 137)
#         Word 3: 'متوسطه' at (547, 138)
#         Word 4: '-' at (534, 138)
#         Word 5: 'دوازدهم' at (481, 138)
#         Word 6: 'تاریخ' at (433, 138)
#         Word 7: 'آزمون' at (397, 138)
#
#   Block 14:
#     Type: 1
#     Confidence: 94.60%
#     Paragraphs: 1
#     Bounding box: (440, 171) to (503, 186)
#       Para 1: 'پاسخبرگ' (conf: 94.60%)
#         Word 1: 'پاسخبرگ' at (440, 171)
#
#   Block 15:
#     Type: 1
#     Confidence: 68.31%
#     Paragraphs: 1
#     Bounding box: (257, 147) to (338, 156)
#       Para 1: '۱۴۰۴/۰۲/۲۵' (conf: 68.31%)
#         Word 1: '۱۴۰۴/۰۲/۲۵' at (257, 147)
#
#   Block 16:
#     Type: 1
#     Confidence: 98.84%
#     Paragraphs: 1
#     Bounding box: (221, 202) to (738, 216)
#       Para 1: 'پاسخهای خود را در محلهای تعیین شده به صورت دقیق خوش خط و مرتب وارد کنید' (conf: 98.84%)
#         Word 1: 'پاسخهای' at (684, 196)
#         Word 2: 'خود' at (653, 197)
#         Word 3: 'را' at (639, 197)
#         Word 4: 'در' at (619, 197)
#         Word 5: 'محلهای' at (560, 198)
#         Word 6: 'تعیین' at (520, 199)
#         Word 7: 'شده' at (488, 200)
#         Word 8: 'به' at (472, 200)
#         Word 9: 'صورت' at (428, 200)
#         Word 10: 'دقیق' at (392, 201)
#         Word 11: 'خوش' at (350, 202)
#         Word 12: 'خط' at (324, 202)
#         Word 13: 'و' at (314, 203)
#         Word 14: 'مرتب' at (278, 203)
#         Word 15: 'وارد' at (251, 204)
#         Word 16: 'کنید' at (221, 204)
#
#   Block 17:
#     Type: 1
#     Confidence: 87.49%
#     Paragraphs: 1
#     Bounding box: (38, 164) to (155, 177)
#       Para 1: 'مدت زمان ۳۰ دقیقه' (conf: 87.49%)
#         Word 1: 'مدت' at (130, 161)
#         Word 2: 'زمان' at (102, 162)
#         Word 3: '۳۰' at (69, 163)
#         Word 4: 'دقیقه' at (38, 164)
#
#   Block 18:
#     Type: 1
#     Confidence: 92.15%
#     Paragraphs: 1
#     Bounding box: (37, 197) to (62, 205)
#       Para 1: 'نمره' (conf: 92.15%)
#         Word 1: 'نمره' at (37, 197)
#
#   Block 19:
#     Type: 1
#     Confidence: 89.77%
#     Paragraphs: 1
#     Bounding box: (719, 469) to (840, 490)
#       Para 1: 'قطرات' (conf: 89.77%)
#         Word 1: 'قطرات' at (719, 469)
#
#   Block 20:
#     Type: 1
#     Confidence: 82.05%
#     Paragraphs: 1
#     Bounding box: (411, 416) to (434, 430)
#       Para 1: 'ب )' (conf: 82.05%)
#         Word 1: 'ب' at (419, 416)
#         Word 2: ')' at (411, 416)
#
#   Block 21:
#     Type: 1
#     Confidence: 88.80%
#     Paragraphs: 1
#     Bounding box: (278, 396) to (367, 431)
#       Para 1: 'نیکوتین' (conf: 88.80%)
#         Word 1: 'نیکوتین' at (278, 396)
#
#   Block 22:
#     Type: 1
#     Confidence: 63.00%
#     Paragraphs: 1
#     Bounding box: (435, 491) to (418, 505)
#       Para 1: 'c )' (conf: 63.00%)
#         Word 1: 'c' at (435, 492)
#         Word 2: ')' at (427, 491)
#
#   Block 23:
#     Type: 1
#     Confidence: 89.16%
#     Paragraphs: 1
#     Bounding box: (257, 457) to (409, 501)
#       Para 1: 'آمونیاک' (conf: 89.16%)
#         Word 1: 'آمونیاک' at (257, 457)
#
#   Block 24:
#     Type: 1
#     Confidence: 90.42%
#     Paragraphs: 2
#     Bounding box: (373, 628) to (849, 741)
#       Para 1: 'کشیدن ضامن تمرکز بر روی آتش' (conf: 94.86%)
#         Word 1: 'کشیدن' at (753, 632)
#         Word 2: 'ضامن' at (677, 632)
#         Word 3: 'تمرکز' at (538, 630)
#         Word 4: 'بر' at (509, 630)
#         Word 5: 'روی' at (453, 629)
#         Word 6: 'آتش' at (373, 629)
#       Para 2: 'اسپری کردن کے فشار آورد' (conf: 85.27%)
#         Word 1: 'اسپری' at (734, 700)
#         Word 2: 'کردن' at (667, 699)
#         Word 3: 'کے' at (602, 699)
#         Word 4: 'فشار' at (513, 698)
#         Word 5: 'آورد' at (424, 696)
#
#   Block 25:
#     Type: 1
#     Confidence: 88.65%
#     Paragraphs: 1
#     Bounding box: (750, 804) to (891, 850)
#       Para 1: '( الف ) گاز' (conf: 88.65%)
#         Word 1: '(' at (884, 813)
#         Word 2: 'الف' at (867, 812)
#         Word 3: ')' at (862, 812)
#         Word 4: 'گاز' at (750, 804)
#
#   Block 26:
#     Type: 1
#     Confidence: 79.14%
#     Paragraphs: 1
#     Bounding box: (410, 826) to (433, 840)
#       Para 1: 'ب )' (conf: 79.14%)
#         Word 1: 'ب' at (418, 826)
#         Word 2: ')' at (410, 826)
#
#   Block 27:
#     Type: 1
#     Confidence: 97.52%
#     Paragraphs: 1
#     Bounding box: (290, 793) to (355, 837)
#       Para 1: 'برق' (conf: 97.52%)
#         Word 1: 'برق' at (290, 793)
#
#   Block 28:
#     Type: 1
#     Confidence: 59.90%
#     Paragraphs: 1
#     Bounding box: (915, 1055) to (934, 1066)
#       Para 1: '۱۳' (conf: 59.90%)
#         Word 1: '۱۳' at (915, 1055)
#
#   Block 29:
#     Type: 1
#     Confidence: 97.60%
#     Paragraphs: 1
#     Bounding box: (732, 882) to (816, 906)
#       Para 1: 'بنزین' (conf: 97.60%)
#         Word 1: 'بنزین' at (732, 882)
#
#   Block 30:
#     Type: 1
#     Confidence: 92.76%
#     Paragraphs: 1
#     Bounding box: (873, 909) to (891, 922)
#       Para 1: 'ج )' (conf: 92.76%)
#         Word 1: 'ج' at (879, 909)
#         Word 2: ')' at (873, 909)
#
#   Block 31:
#     Type: 1
#     Confidence: 88.44%
#     Paragraphs: 1
#     Bounding box: (762, 981) to (896, 1013)
#       Para 1: '( الف ) دوچر' (conf: 88.44%)
#         Word 1: '(' at (887, 985)
#         Word 2: 'الف' at (866, 985)
#         Word 3: ')' at (859, 984)
#         Word 4: 'دوچر' at (762, 981)
#
#   Block 32:
#     Type: 1
#     Confidence: 79.54%
#     Paragraphs: 1
#     Bounding box: (865, 1067) to (887, 1080)
#       Para 1: 'ب )' (conf: 79.54%)
#         Word 1: 'ب' at (872, 1067)
#         Word 2: ')' at (865, 1068)
#
#   Block 33:
#     Type: 1
#     Confidence: 90.94%
#     Paragraphs: 1
#     Bounding box: (432, 1177) to (514, 1196)
#       Para 1: 'موفق باشید .' (conf: 90.94%)
#         Word 1: 'موفق' at (479, 1179)
#         Word 2: 'باشید' at (436, 1178)
#         Word 3: '.' at (432, 1178)
#
#   Block 34:
#     Type: 1
#     Confidence: 55.10%
#     Paragraphs: 1
#     Bounding box: (28, 586) to (41, 569)
#       Para 1: 'i >' (conf: 55.10%)
#         Word 1: 'i' at (28, 586)
#         Word 2: '>' at (28, 584)
#
#   Block 35:
#     Type: 1
#     Confidence: 85.44%
#     Paragraphs: 1
#     Bounding box: (32, 572) to (44, 584)
#       Para 1: 'A' (conf: 85.44%)
#         Word 1: 'A' at (32, 572)
#
#   Block 36:
#     Type: 1
#     Confidence: 73.37%
#     Paragraphs: 1
#     Bounding box: (27, 688) to (32, 699)
#       Para 1: '1' (conf: 73.37%)
#         Word 1: '1' at (27, 688)
#
#   Block 37:
#     Type: 1
#     Confidence: 80.61%
#     Paragraphs: 1
#     Bounding box: (19, 852) to (42, 863)
#       Para 1: '۱.۵' (conf: 80.61%)
#         Word 1: '۱.۵' at (19, 852)
#
#   Block 38:
#     Type: 1
#     Confidence: 70.17%
#     Paragraphs: 1
#     Bounding box: (42, 1154) to (57, 1164)
#       Para 1: '۲۰' (conf: 70.17%)
#         Word 1: '۲۰' at (42, 1154)
#
# Total paragraphs found: 39
